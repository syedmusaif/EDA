# %%
# dtaset name is : Visadataset
# Saved in a folder

# %% [markdown]
# **Import the required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#    import pandas as pd
#   import numpy as np
#    import matplotib.pyplot as plt
#    import seaborn as sns
    
    
#    import pandas as pd 
 #   import numpy as np 
#    import matplotlib.pyplot as plt
#    import seaborn as sns 
    
#    import pandas as pd 
#    import numpy as np
#    import matplot.pyplot as plt
#    import seaborn as sns

# %%
**Read the data**

# %% [markdown]
# - Here we are reading visa dataset
#
# - Which is csv type : comma seperated value
#
# - It is located in Datafile folder
#
# - in order to read any dataset
#
#   - Directory
#
#   - filename
#
#   - type

# %%
path=r"C:\Users\syedh\Downloads\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\syedh\Downloads\Visadataset.csv"

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.read_csv(path,sep=';')
# Out:
#       case_id,continent,education_of_employee,has_job_experience,requires_job_training,no_of_employees,yr_of_estab,region_of_employment,prevailing_wage,unit_of_wage,full_time_position,case_status
# 0      EZYV01,Asia,High School,N,N,14513,2007,West,59...
# 1      EZYV02,Asia,Master's,Y,N,2412,2002,Northeast,8...
# 2      EZYV03,Asia,Bachelor's,N,Y,44444,2008,West,122...
# 3      EZYV04,Asia,Bachelor's,N,N,98,1897,West,83434....
# 4      EZYV05,Africa,Master's,Y,N,1082,2005,South,149...
# ...                                                  ...
# 25475  EZYV25476,Asia,Bachelor's,Y,Y,2601,2008,South,...
# 25476  EZYV25477,Asia,High School,Y,N,3274,2006,North...
# 25477  EZYV25478,Asia,Master's,Y,N,1121,1910,South,14...
# 25478  EZYV25479,Asia,Master's,Y,Y,1918,1887,West,861...
# 25479  EZYV25480,Asia,Bachelor's,Y,N,3195,1960,Midwes...
#
# [25480 rows x 1 columns]

# %% [markdown]
# **Data quick checks**
#
# - head
#
# - tail
#
# - shape
#
# - size
#
# - column
#
# - dtpyes
#
# - info
#
# - take
#
# - loc

# %% [markdown]
# $Head$

# %%
#<package_name>.<method_name>

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %% [markdown]
# $tail$

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.tail(15)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25467  EZYV25468  North America              Master's                  N
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# ...

# %% [markdown]
# $shape$

# %%
visa_df.shape
# Out:
# (25480, 12)

# %% [markdown]
# $Size$

# %%
visa_df.size
# Out:
# 305760

# %% [markdown]
# **rows*columns**

# %%
visa_df.shape[0]*visa_df.shape[1]
# Out:
# 305760

# %% [markdown]
# $Columns$

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# $len$

# %%
len(visa_df.columns)
# Out:
# 12

# %%
len(visa_df)
# Out:
# 25480

# %% [markdown]
# $dtypes$
#
# - It will provide each column data type
#
# - Object means string data type ( Categorical )
#
# - int64,int32,int28,float64(Numerical)
#
# - dtype always give in series

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %%
**task-1**

- I want to create two list

- one categorical column list

- secound one is numerical

-
# Out:
#   Cell In[30], line 1
#     **task-1**
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# - whwenever you waant to create any list from series
#
# - frist convert the series into a dictionary
#
# - when you convert it becamce a key:value pair
#
# - lterate throught dictionary
#
# - if that value == object type , then keep that corresponding

# %%
data_types=visa_df.dtypes
dict(data_types)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
cat_list=[]
num_list=[]
for i,j in dict(data_types).items( ):
    print(i,j)
    if j=='object':
        cat_list.append(i)
    else:
        num_list.append(i)
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# no_of_employees int64
# yr_of_estab int64
# region_of_employment object
# prevailing_wage float64
# unit_of_wage object
# full_time_position object
# case_status object

# %%
cat_list=[i for i,j in dict(data_types).items( ) if j== 'object']
num_list=[j for i,j in dict(data_types).items( ) if j!='object']
cat_list,num_list
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  [dtype('int64'), dtype('int64'), dtype('float64')])

# %%
- create two list

- creatw two data freams
# Out:
#   Cell In[34], line 1
#     - create two list
#              ^
# SyntaxError: invalid syntax

# %%
len(cat_list),len(num_list)
# Out:
# (9, 3)

# %%
- We can not create a dataframe using these two list 

- Because these two list are not in equal length

- if you want  to create a dataframe ,thenwe needto givse

  - then you need to question yourelf

  -
# Out:
#   Cell In[36], line 1
#     - We can not create a dataframe using these two list
#          ^
# SyntaxError: invalid syntax

# %%
num_df=pd.DataFrame(num_list,columns=['Numercial_column'])
num_df.to_csv('Numercial_column_df.csv',index=False)

# %%
cat_df=pd.DataFrame(cat_list,columns=['Categorical_column'])
cat_df.to_csv('Categorical_column_df.csv',index=False)

# %% [markdown]
# **task-2**

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
dict(visa_df.dtypes).keys()
# Out:
# dict_keys(['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'no_of_employees', 'yr_of_estab', 'region_of_employment', 'prevailing_wage', 'unit_of_wage', 'full_time_position', 'case_status'])

# %%
dict(visa_df.dtypes).values()
# Out:
# dict_values([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'), dtype('O'), dtype('O'), dtype('O')])

# %%
cols,data_types=[],[]
for keys ,values in dict(visa_df.dtypes).items():
    cols.append()
    data_types()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 cols,data_types=[],[]
#       2 for keys ,values in dict(visa_df.dtypes).items():
# ----> 3     cols.append()
#       4     data_types()
#
# TypeError: list.append() takes exactly one argument (0 given)

# %% [markdown]
# **Task-3**
#
# **we can create a data frame using dictionary also**

# %%
dict1={'Name':['Ashish','Mohit','Manish'],
       'Age':[30,40,60]}
dict1
# Out:
# {'Name': ['Ashish', 'Mohit', 'Manish'], 'Age': [30, 40, 60]}

# %%
pd.DataFrame(dict1)
# Out:
#      Name  Age
# 0  Ashish   30
# 1   Mohit   40
# 2  Manish   60

# %%
- the advantage : no  need to provide column names again

- Automatically Keys behave as column names

# %% [markdown]
# **Task-4**

# %% [markdown]
# - we have two list are there
#
# - cols,data_types
#
# - create a dictionary with these two
#
# - And make a dataframe

# %%
d={}
cols=d['Columns']
data_type=d['Data type']
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
#       1 d={}
# ----> 2 cols=d['Columns']
#       3 data_type=d['Data type']
#       4 pd.DataFrame(d)
#
# KeyError: 'Columns'

# %%
pd.DataFrame(zip(cols,data_types),
            columns='Columns','Data type')
# Out:
#   Cell In[49], line 2
#     columns='Columns','Data type')
#                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# task is 

- list to dataframe

- Dictionary to datafamre 

- list---->Dict---->

-Dict---->list----->
# Out:
#   Cell In[58], line 3
#     - list to dataframe
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# **isnull**
#
# - Null means element is missed
#
# - Missing values
#
# - isnull we are asking  QUESTion to the computer is any element missed or not?
#
# - then computer will give True or False
#
# - True : yes the value not missed
#
# - False : no the value not missed

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
import pandas as pd
import numpy as np 
import matlotlib.pyplot as plt
immport seaborn sns

# %% [markdown]
# - Head
#
# - tail
#
# - shape
#
# - size
#
# - columns
#
# - dtypes
#
# - isnull
#
# - isnull().sum()
#
# - isna
#
# - info

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# $info$

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $take$
#
# - first argument : indices
#
# - indices will take some value in array : in list
#
# - It tries to extract the data
#
# - that values we provided represents columns or rows??
#
# - axis=0 represents about rows
#
# - axis-1 represents about columns
#
# - by default axis mentioned as zero

# %%
visa_df.take([100,200,300])
# It retrives 3 rows which having index 100,200,300
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
# case-2
visa_df.take([100,200,300],axis=1)
# now this will check for 100 column and 200 column and 300 column 
# but originally we have only 12 column (0,11)
# will get error
# Out:
#   Cell In[66], line 1
#     visa_df.take([100,200,300]),axis=1
#                                 ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# case-3 select 3column 2,5,7 
# using tak
visa_df.take([2,5,7],axis=1)
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
#case-4: Slicing will fail
visa_df.take([2:5])
# Out:
#   Cell In[53], line 2
#     visa_df.take([[2:5]])
#                     ^
# SyntaxError: invalid syntax

# %%
#question is:
# we want 100,200,300 row from
# 2,5,7

# %% [markdown]
# **Loc-iloc**

# %%
visa_df.iloc[<rows>,<columns>]
visa_df.iloc[start:stop,start:stop]
visa_df.iloc[start:stop:step,start:stop:step]
visa_df.iloc[[list of rows],[list of column]]

# %%
visa_df.iloc[[100,200,300],[2,5,7,8]]
# Out:
#     education_of_employee  no_of_employees region_of_employment  \
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest
#
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21

# %%
visa_df.iloc[100:105,2:7]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 101              334         2007
# 102              224         2008
# 103              367         1982
# 104              306         2003

# %%
visa_df.iloc[100:105,[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 101              Master's              334              Midwest
# 102            Bachelor's              224              Midwest
# 103             Doctorate              367                 West
# 104              Master's              306            Northeast

# %%
visa_df.iloc[100:200:50,2:5:2]
# Out:
#     education_of_employee requires_job_training
# 100              Master's                     N
# 150            Bachelor's                     N

# %%
visa_df.iloc[:]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[:,2]
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df.iloc[[2,5,7]]
visa_df.iloc[:,[2,5,7]]
visa_df.iloc[:,2]
visa_df.iloc[:,[2]]
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %%
visa_df.iloc[:,[]]

# %%
cols=['Number','Square']
df2[cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 cols=['Number','Square']
# ----> 2 df2[cols]
#
# NameError: name 'df2' is not defined
